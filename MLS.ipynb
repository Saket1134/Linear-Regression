# %% [markdown]
# **Multiple Linear Regression by Sklearn**

# %%
import numpy as np

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0  0.068484 -0.617542 -41.500466
# 1  1.266786 -0.020999  39.189556
# 2  0.634952  0.188133  26.524831
# 3  1.230167 -1.253537 -17.944057
# 4 -0.454104  0.789479  43.540533

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 2046.3951391615508
# R2 Score: 0.8628450678709292
# Mean Absolute Error: 36.31764265754116

# %%
lr.coef_
# Out:
# array([57.23646127, 77.81572458])

# %%
lr.intercept_
# Out:
# np.float64(0.49085891981675456)

# %% [markdown]
# **Using class Multiple Linear Regression**

# %%
class MultipleLinearRegression:
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
    def fit(self,X_train,y_train):
            X_train = np.insert(X_train,0,1,axis=1)
            betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
            self.intercept_ = betas[0]
            self.coef_ = betas[1:]
            print(self.intercept_,self.coef_)
    def predict(self,X_test):
            y_pred = np.dot(X_test,self.coef_) + self.intercept_
            return y_pred

# %%
lr=MultipleLinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# 0.49085891981674656 [57.23646127 77.81572458]

# %%
lr.coef_
# Out:
# array([57.23646127, 77.81572458])

# %%
lr.intercept_
# Out:
# np.float64(0.49085891981674656)

# %%
r2_score(y_test,lr.predict(X_test))
# Out:
# 0.8628450678709292
